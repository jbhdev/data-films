# %%
import pandas as pd
import os

movie = pd.read_csv('../datasets/raw/movie_tmdb_ajout.csv')
movie
# Out:
#       adult                     backdrop_path  \
# 0     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg
# 1     False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg
# 2     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg
# 3     False  /cJvUJEEQ86LSjl4gFLkYpdCJC96.jpg
# 4     False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg
# ...     ...                               ...
# 7466  False                               NaN
# 7467  False  /2Ax5PQbSFG1ohuXkkizn2EAJ3MV.jpg
# 7468  False  /7czN2VNvlC4xR3JsgLdYwb1o8pQ.jpg
# 7469  False                               NaN
# 7470  False  /f6bq9YGR04of21OrcHwVbqydZS8.jpg
#
#                                   belongs_to_collection     budget  \
# 0     {'id': 1461530, 'name': 'Minecraft - Saga', 'p...  150000000
# 1     {'id': 8864, 'name': 'Destination Finale - Sag...   50000000
# 2                                                   NaN   40000000
# 3                                                   NaN   20000000
# 4                                                   NaN  270000000
# ...
