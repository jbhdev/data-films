# %%
import pandas as pd
import os

movie = pd.read_csv('../datasets/raw/movie_new.csv')
movie
# Out:
#        adult                     backdrop_path            genre_ids       id  \
# 0      False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg  [10751, 35, 12, 14]   950387
# 1      False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg           [27, 9648]   574475
# 2      False                               NaN             [28, 53]  1480799
# 3      False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg         [28, 80, 53]  1197306
# 4      False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg          [10751, 14]   447273
# ...      ...                               ...                  ...      ...
# 32875  False  /op3qmNhvwEvyT7UFyPbIfQmKriB.jpg         [28, 14, 12]   324544
# 32876  False  /8eifdha9GQeZAkexgtD45546XKx.jpg        [28, 53, 878]   822119
# 32877  False  /3MA11b8nXMEI29MGHIeFfp14YdN.jpg        [53, 878, 27]  1180763
# 32878  False  /65MVgDa6YjSdqzh7YOA04mYkioo.jpg         [28, 80, 53]   668489
# 32879  False  /12tEzU0bNYKIjXXEwI5abuOotHF.jpg                 [37]   710258
#
# ...
