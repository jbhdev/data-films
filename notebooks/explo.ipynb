# %%
import pandas as pd
import os

movie = pd.read_csv('../datasets/raw/movies_tmdb.csv')
movie
# Out:
#       adult                     backdrop_path            genre_ids       id  \
# 0     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg  [10751, 35, 12, 14]   950387
# 1     False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg           [27, 9648]   574475
# 2     False                               NaN             [28, 53]  1480799
# 3     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg         [28, 80, 53]  1197306
# 4     False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg          [10751, 14]   447273
# ...     ...                               ...                  ...      ...
# 9994  False  /cdEVfwkVwFeL9LuTlGHTfezso8C.jpg          [10752, 18]  1047925
# 9995  False  /4uSkLpsGnD7xExBRzuV3IH8fT3O.jpg          [18, 10749]   585561
# 9996  False  /rnD4FFfD0kKgbiePbiEn5nPtry2.jpg          [10749, 18]   298094
# 9997  False  /7295GnkwMbNcHLEXkQkLNIWNa39.jpg      [35, 18, 10752]   279641
# 9998  False   /QAnuNwYnnttSkBkvUBwQYf8cKD.jpg     [878, 35, 10751]    22345
#
#      original_language                original_title  \
# ...
