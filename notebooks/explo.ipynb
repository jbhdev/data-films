# %%
import pandas as pd
import os

movie = pd.read_csv('../datasets/raw/df_filtered.csv')
movie
# Out:
#       adult                     backdrop_path  \
# 0     False  /2Nti3gYAX513wvhp8IiLL6ZDyOm.jpg
# 1     False  /j0NUh5irX7q2jIRtbLo8TZyRn6y.jpg
# 2     False  /fTrQsdMS2MUw00RnzH0r3JWHhts.jpg
# 3     False  /tyfO9jHgkhypUFizRVYD0bytPjP.jpg
# 4     False  /cJvUJEEQ86LSjl4gFLkYpdCJC96.jpg
# ...     ...                               ...
# 7460  False  /f6bq9YGR04of21OrcHwVbqydZS8.jpg
# 7461  False                               NaN
# 7462  False                               NaN
# 7463  False  /vlxj1L5kugK2IcGzUoJDu3ckaiN.jpg
# 7464  False                               NaN
#
#                                   belongs_to_collection     budget  \
# 0     {'id': 1461530, 'name': 'Minecraft - Saga', 'p...  150000000
# 1     {'id': 8864, 'name': 'Destination Finale - Sag...   50000000
# 2                                                   NaN   40000000
# 3                                                   NaN  270000000
# 4                                                   NaN   20000000
# ...
